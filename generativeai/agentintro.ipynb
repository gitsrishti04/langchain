# %%
import os
from dotenv import load_dotenv

load_dotenv()
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain.tools import tool

@tool
def get_weather(location: str) -> str:
    """Get the weather for a location."""
    return f"The weather in {location} is sunny."

# %%
from langchain_groq import ChatGroq
from langchain.agents import create_react_agent, AgentExecutor
from langchain_core.prompts import ChatPromptTemplate

# %%
model = ChatGroq(
    model="qwen/qwen3-32b"
)

# %%
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant that can answer questions about the weather."),
    ("human", "{input}"),
    ("placeholder", "{agent_scratchpad}")
])

# %%
agent = create_react_agent(
    llm=model,
    tools=[get_weather],
    prompt=prompt
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 agent = create_react_agent(
#       2     llm=model,
#       3     tools=[get_weather],
#       4     prompt=prompt
#       5 )
#
# File ~/Desktop/langchain/.venv/lib/python3.9/site-packages/langchain/agents/react/agent.py:125, in create_react_agent(llm, tools, prompt, output_parser, tools_renderer, stop_sequence)
#     123 if missing_vars:
#     124     msg = f"Prompt missing required variables: {missing_vars}"
# --> 125     raise ValueError(msg)
#     127 prompt = prompt.partial(
#     128     tools=tools_renderer(list(tools)),
#     129     tool_names=", ".join([t.name for t in tools]),
#     130 )
#     131 if stop_sequence:
#
# ValueError: Prompt missing required variables: {'tools', 'tool_names'}
