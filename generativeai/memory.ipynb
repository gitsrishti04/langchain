# %%
import os
from dotenv import load_dotenv
load_dotenv()
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

# %%
agent=create_agent(
    model="groq:llama-3.1-8b-instant",
    checkpointer=InMemorySaver()
)

# %%
###Run with thread id
config={"configurable":{"thread_id":"test1"}}

# %%
from langchain_core.messages import HumanMessage, SystemMessage
response=agent.invoke({"messages": [HumanMessage(content="Hi my name is Srishti!")]},config=config)
response
# Out:
# {'messages': [HumanMessage(content='Hi my name is Srishti!', additional_kwargs={}, response_metadata={}, id='170dbc13-75c4-4015-a032-deb08b5bd516'),
#   AIMessage(content='Nice to meet you, Srishti! How are you doing today? Is there anything I can help you with or would you like to chat?', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 31, 'prompt_tokens': 43, 'total_tokens': 74, 'completion_time': 0.037422858, 'completion_tokens_details': None, 'prompt_time': 0.002094845, 'prompt_tokens_details': None, 'queue_time': 0.055541942, 'total_time': 0.039517703}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c2535-9c09-71d0-8b44-0ebeff7a4f74-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 43, 'output_tokens': 31, 'total_tokens': 74})]}

# %%
agent.invoke({"messages":[HumanMessage(content="Hi what is my name")]}, config = config)
# Out:
# {'messages': [HumanMessage(content='Hi my name is Srishti!', additional_kwargs={}, response_metadata={}, id='170dbc13-75c4-4015-a032-deb08b5bd516'),
#   AIMessage(content='Nice to meet you, Srishti! How are you doing today? Is there anything I can help you with or would you like to chat?', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 31, 'prompt_tokens': 43, 'total_tokens': 74, 'completion_time': 0.037422858, 'completion_tokens_details': None, 'prompt_time': 0.002094845, 'prompt_tokens_details': None, 'queue_time': 0.055541942, 'total_time': 0.039517703}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c2535-9c09-71d0-8b44-0ebeff7a4f74-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 43, 'output_tokens': 31, 'total_tokens': 74}),
#   HumanMessage(content='Hi what is my name', additional_kwargs={}, response_metadata={}, id='ebc81ad4-314b-476f-a369-322e2e0fe83d'),
#   AIMessage(content='Your name is Srishti.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 88, 'total_tokens': 96, 'completion_time': 0.005279128, 'completion_tokens_details': None, 'prompt_time': 0.004834726, 'prompt_tokens_details': None, 'queue_time': 0.051486021, 'total_time': 0.010113854}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_ff2b098aaf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c2535-e614-7850-82e8-14aa9ed15a27-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 88, 'output_tokens': 8, 'total_tokens': 96})]}
